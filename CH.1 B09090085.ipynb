# %%
#變數
a=3  
b=5
print(a+b)
'''
多行註解
多行註解
多行註解
'''
a=3
b=5
print(a+b)

x=1
y=10

z=x
x=y
y=z
print(x)
print(y)
x=1
y=10
#運算子
x=x+y
y=x-y
x=x-y
print(x)
print(y)
#變數多行
x=1
y=10
x,y = y,x
print(x)
print(y)
x, y, z= 3, 4, 5
print(x)
print(y)
print(z)
#乘法
x, y, z = 3, 4, 5
x += 1 
y *= 2 
z **= 3 
print(x, y, z)
#屬性
x=254
print(type(x))
y=254.0
print(type(y))
z='write'
print(type(z))
print(type(x==y))
#除、商；餘數
x=10
y=3
print(x/y)  
print(x//y) 
print(x%y)  
#字串相加
print("This", "is", "a", "book")
print("This"+"is"+"a"+"book")

print("This {} a book".format("is"))
x=123456.7890
print("{:.2f}".format(x))  
print("{:,.2f}".format(x))
# Out:
# 8
# 8
# 10
# 1
# 10
# 1
# 10
# 1
# 3
# 4
# 5
# 4 8 125
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# 3.3333333333333335
# 3
# 1
# This is a book
# Thisisabook
# This is a book
# 123456.79
# 123,456.79
